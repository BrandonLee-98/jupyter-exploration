# %% [markdown]
# # My first markdown cell in Jupyter.
# Intro to Jupyter - 6262-ITAI-2373-Natural Language Processing-RT-14424 In this session we are learning the basics of Jupyter.

# %%
print("Hello World!")
print("My name is Brandon Matias.")
print("Welcome to my Jupyter Notebook!")
# Out:
# Hello World!
# My name is Brandon Matias.
# Welcome to my Jupyter Notebook!
